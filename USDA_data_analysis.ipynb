# %% [markdown]
# # for fy12 to fy 22

# %%
import pandas as pd
import os

# Define the directory containing the data files
data_dir = r'/Users/adityakadam/Desktop/Python_Repository/usda_data_analytics'

# Initialize an empty list to store the DataFrames
dfs = []

# Loop through the files from FY12 to FY22
for i in range(12, 22):
    filename = f'FY{i:02d}.xlsx'  # Adjusted for .xlsx file extension
    filepath = os.path.join(data_dir, filename)

    # Verify if file exists
    if not os.path.exists(filepath):
        print(f"File not found: {filepath}")
        continue

    # Read the Excel file into a DataFrame, skipping the first row and specifying sheet name if necessary
    try:
        df = pd.read_excel(filepath, skiprows=2, header=None, engine="openpyxl", 
                           names=['Origin State', 'Material Group Code',
                                  'Material Group Description','Material Code',
                                  'Material Description', 'Purchased Quantity LB',
                                  'Purchased Value $'])
    except ValueError as e:
        print(f"Error reading {filepath}: {e}")
        continue

    # Add a 'Year' column to identify the year number
    df['Year'] = f'20{i}'

    # Append the DataFrame to the list
    dfs.append(df)

# Concatenate all DataFrames in the list into a single DataFrame
if dfs:  # Only proceed if there are valid DataFrames
    all_data = pd.concat(dfs, ignore_index=True)

    # Reorder columns (optional)
    usda_1221_df = all_data[['Year', 'Origin State', 
                         'Material Group Description',
                         'Material Description', 'Purchased Quantity LB', 
                         'Purchased Value $']]

    # Save to CSV
    usda_1221_df.to_csv('usda_12to21_dataset.csv', index=False)
    print("Successfully merged data.")
    print(all_data.head())
else:
    print("No valid data was processed.")
# Out:
# Successfully merged data.
#   Origin State Material Group Code Material Group Description Material Code  \
# 0           AK            205030.0               FISH, FROZEN      100892.0
# 1           AK            205010.0               FISH, CANNED      100198.0
# 2           AK            205010.0               FISH, CANNED      100198.0
# 3           AK            205010.0               FISH, CANNED      100198.0
# 4           AK            205010.0               FISH, CANNED      100198.0
#
#                Material Description Purchased Quantity LB Purchased Value $  \
# 0  FISH AK PLCK FRZ BULK CTN-49 LBS             1199520.0         2051179.2
# 1       SALMON PINK CAN-24/14.75 OZ               35400.0           82800.0
# 2       SALMON PINK CAN-24/14.75 OZ              247800.0          626688.0
# 3       SALMON PINK CAN-24/14.75 OZ              106200.0          268016.0
# 4       SALMON PINK CAN-24/14.75 OZ              672600.0         1710112.0
#
#    Year
# 0  2012
# 1  2012
# 2  2012
# 3  2012
# 4  2012

# %%
usda_1221_data = pd.read_csv('usda_12to21_dataset.csv')
usda_1221_df = pd.DataFrame(usda_1221_data)
usda_1221_df = usda_1221_df.dropna().reset_index(drop=True)

# %% [markdown]
# # for fy11 data

# %%
usda_11_data = pd.read_excel('FY11.xlsx', skiprows=1)
usda_11_df = pd.DataFrame(usda_11_data)
usda_11_df['Year'] = '2011'

# %%
usda_11_df = usda_11_df[['Year','Origin State','Material Group Description','Material Description','Purchased Quantity LB','Purchased Value $']]
usda_11_df = usda_11_df.dropna().reset_index(drop=True)

# %%
usda_11_df.to_csv('usda_11_dataset.csv')

# %%
usda_11_df
# Out:
#       Year Origin State Material Group Description  \
# 0     2011           AK               FISH, CANNED
# 1     2011           AK               FISH, CANNED
# 2     2011           AK               FISH, FROZEN
# 3     2011           AL            CHICKEN, FROZEN
# 4     2011           AL              CHICKEN, BULK
# ...    ...          ...                        ...
# 1252  2011           WI          VEGETABLE, CANNED
# 1253  2011           WI          VEGETABLE, CANNED
# 1254  2011           WV            CHICKEN, FROZEN
# 1255  2011           WV              CHICKEN, BULK
# 1256  2011           WV              CHICKEN, BULK
#
#                          Material Description  Purchased Quantity LB  \
# 0                 SALMON PINK CAN-24/14.75 OZ              1912042.5
# 1                 SALMON PINK CAN-24/14.75 OZ              3371850.0
# 2            FISH AK PLCK FRZ BULK CTN-49 LBS              1759296.0
# 3                CHICKEN CUT-UP FRZ CTN-40 LB               320000.0
# 4                 CHICKEN SMALL CHILLED -BULK              1440000.0
# ...                                       ...                    ...
# 1252                          PEAS CAN-24/300              2806650.0
# 1253           POTATOES WHT SLICES CAN-24/300              5544720.0
# 1254  CHICKEN OVEN ROASTED FRZ 8 PC CTN-30 LB              2736000.0
# 1255              CHICKEN SMALL CHILLED -BULK              7344000.0
# 1256              CHICKEN SMALL CHILLED -BULK              5192640.0
#
#       Purchased Value $
# 0            4393252.20
# 1            6189008.00
# 2            2726908.80
# 3             239952.00
# 4            1047960.00
# ...                 ...
# 1252         1206965.00
# 1253         2083930.00
# 1254         6831145.00
# 1255         5534943.00
# 1256         3959181.12
#
# [1257 rows x 6 columns]

# %% [markdown]
# # for fy22 and fy23 data

# %%
import pandas as pd
import os

# Define the directory containing the data files
data_dir = r'/Users/adityakadam/Desktop/Python_Repository/usda_data_analytics'

# Initialize an empty list to store the DataFrames
dfs = []

# Loop through the files from FY22 to FY23
for i in range(22, 24):
    filename = f'FY{i:02d}.xlsx'  # Adjusted for .xlsx file extension
    filepath = os.path.join(data_dir, filename)

    # Verify if file exists
    if not os.path.exists(filepath):
        print(f"File not found: {filepath}")
        continue

    # Read the Excel file into a DataFrame, skipping the first row and specifying sheet name if necessary
    try:
        df = pd.read_excel(filepath, skiprows=2, header=None, engine="openpyxl", 
                           names=['Origin State', 'Material Group Description','Material Code',
                                  'Material Description','Purchased Quantity LB',
                                  'Purchased Value $'])
    except ValueError as e:
        print(f"Error reading {filepath}: {e}")
        continue

    # Add a 'Year' column to identify the year number
    df['Year'] = f'20{i}'

    # Append the DataFrame to the list
    dfs.append(df)

# Concatenate all DataFrames in the list into a single DataFrame
if dfs:  # Only proceed if there are valid DataFrames
    all_data = pd.concat(dfs, ignore_index=True)

    # Reorder columns (optional)
    usda_2223_df = all_data[['Year','Origin State','Material Group Description',
                         'Material Description','Purchased Quantity LB',
                         'Purchased Value $']]
    
    usda_2223_df = usda_2223_df.dropna()
    
    # Save to CSV
    usda_2223_df.to_csv('usda_22to23_dataset.csv', index=False)
    print("Successfully merged data.")
    print(usda_2223_df.head())
else:
    print("No valid data was processed.")
# Out:
# Successfully merged data.
#    Year Origin State Material Group Description  \
# 0  2022           AK               FISH, CANNED
# 1  2022           AK               FISH, CANNED
# 2  2022           AK               FISH, CANNED
# 3  2022           AK               FISH, CANNED
# 4  2022           AK               FISH, CANNED
#
#                     Material Description  Purchased Quantity LB  \
# 0  K SALMON PINK CAN-24/14.75 OZ (33630)               269040.0
# 1    SALMON PINK CAN-24/14.75 OZ (33630)              1008900.0
# 2             SALMON RED CAN-24/14.75 OZ               739860.0
# 3    SALMON PINK CAN-24/14.75 OZ (33630)               571710.0
# 4    SALMON PINK CAN-24/14.75 OZ (33630)             14326380.0
#
#    Purchased Value $
# 0           827837.6
# 1          3003200.8
# 2          4986664.0
# 3          1748912.0
# 4         45362971.2

# %%
usda_2223_df
# Out:
#       Year Origin State Material Group Description  \
# 0     2022           AK               FISH, CANNED
# 1     2022           AK               FISH, CANNED
# 2     2022           AK               FISH, CANNED
# 3     2022           AK               FISH, CANNED
# 4     2022           AK               FISH, CANNED
# ...    ...          ...                        ...
# 8917  2023           WI          VEGETABLE, FROZEN
# 8918  2023           WI          VEGETABLE, FROZEN
# 8919  2023           WI          VEGETABLE, FROZEN
# 8920  2023           WI          VEGETABLE, FROZEN
# 8921  2023           WI          VEGETABLE, FROZEN
#
#                        Material Description  Purchased Quantity LB  \
# 0     K SALMON PINK CAN-24/14.75 OZ (33630)               269040.0
# 1       SALMON PINK CAN-24/14.75 OZ (33630)              1008900.0
# 2                SALMON RED CAN-24/14.75 OZ               739860.0
# 3       SALMON PINK CAN-24/14.75 OZ (33630)               571710.0
# 4       SALMON PINK CAN-24/14.75 OZ (33630)             14326380.0
# ...                                     ...                    ...
# 8917                 CORN FRZ CTN-12/2.5 LB               158400.0
# 8918                 CORN FRZ CTN-12/2.5 LB               396000.0
# 8919         MIXED VEGETABLES FRZ CTN-6/5LB                79200.0
# 8920                     CORN FRZ CTN-30 LB              3009600.0
# 8921               PEAS GREEN FRZ CTN-30 LB                39600.0
#
#       Purchased Value $
# 0              827837.6
# 1             3003200.8
# 2             4986664.0
# 3             1748912.0
# 4            45362971.2
# ...                 ...
# 8917           144025.2
# 8918           378358.2
# 8919            72732.0
# 8920          2338987.2
# 8921            37382.4
#
# [8833 rows x 6 columns]

# %%
all_usda_df = pd.concat([usda_11_df,usda_1221_df,usda_2223_df],axis=0)
all_usda_df
# Out:
#       Year Origin State Material Group Description  \
# 0     2011           AK               FISH, CANNED
# 1     2011           AK               FISH, CANNED
# 2     2011           AK               FISH, FROZEN
# 3     2011           AL            CHICKEN, FROZEN
# 4     2011           AL              CHICKEN, BULK
# ...    ...          ...                        ...
# 8917  2023           WI          VEGETABLE, FROZEN
# 8918  2023           WI          VEGETABLE, FROZEN
# 8919  2023           WI          VEGETABLE, FROZEN
# 8920  2023           WI          VEGETABLE, FROZEN
# 8921  2023           WI          VEGETABLE, FROZEN
#
#                   Material Description Purchased Quantity LB Purchased Value $
# 0          SALMON PINK CAN-24/14.75 OZ             1912042.5         4393252.2
# 1          SALMON PINK CAN-24/14.75 OZ             3371850.0         6189008.0
# 2     FISH AK PLCK FRZ BULK CTN-49 LBS             1759296.0         2726908.8
# 3         CHICKEN CUT-UP FRZ CTN-40 LB              320000.0          239952.0
# 4          CHICKEN SMALL CHILLED -BULK             1440000.0         1047960.0
# ...                                ...                   ...               ...
# 8917            CORN FRZ CTN-12/2.5 LB              158400.0          144025.2
# 8918            CORN FRZ CTN-12/2.5 LB              396000.0          378358.2
# 8919    MIXED VEGETABLES FRZ CTN-6/5LB               79200.0           72732.0
# 8920                CORN FRZ CTN-30 LB             3009600.0         2338987.2
# 8921          PEAS GREEN FRZ CTN-30 LB               39600.0           37382.4
#
# [36016 rows x 6 columns]

# %%
cleaned_usda = all_usda_df.copy()

# %%
import pandas as pd
cleaned_usda['Year'] = cleaned_usda['Year'].astype(str)

# %%
cleaned_usda = cleaned_usda.rename(columns={'Unnamed: 0':'Index'})
cleaned_usda.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 36016 entries, 0 to 8921
# Data columns (total 6 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Year                        36016 non-null  object
#  1   Origin State                36016 non-null  object
#  2   Material Group Description  36016 non-null  object
#  3   Material Description        36016 non-null  object
#  4   Purchased Quantity LB       36016 non-null  object
#  5   Purchased Value $           36016 non-null  object
# dtypes: object(6)
# memory usage: 1.9+ MB

# %%
add_wy = {
    'Year': 'Not Available',
    'Origin State':'WY',
    'Material Group Description':'Not Available',
    'Material Description':'Not Available',
    'Purchased Quantity LB':'0.0',
    'Purchased Value $':'0.0'
}

add_wy_df = pd.DataFrame([add_wy])

# %%
add_wy_df
# Out:
#             Year Origin State Material Group Description Material Description  \
# 0  Not Available           WY              Not Available        Not Available
#
#   Purchased Quantity LB Purchased Value $
# 0                   0.0               0.0

# %%
cleaned_usda = pd.concat([cleaned_usda,add_wy_df],axis=0)
cleaned_usda.reset_index(drop=True)
# Out:
#                 Year Origin State Material Group Description  \
# 0               2011           AK               FISH, CANNED
# 1               2011           AK               FISH, CANNED
# 2               2011           AK               FISH, FROZEN
# 3               2011           AL            CHICKEN, FROZEN
# 4               2011           AL              CHICKEN, BULK
# ...              ...          ...                        ...
# 36012           2023           WI          VEGETABLE, FROZEN
# 36013           2023           WI          VEGETABLE, FROZEN
# 36014           2023           WI          VEGETABLE, FROZEN
# 36015           2023           WI          VEGETABLE, FROZEN
# 36016  Not Available           WY              Not Available
#
#                    Material Description Purchased Quantity LB  \
# 0           SALMON PINK CAN-24/14.75 OZ             1912042.5
# 1           SALMON PINK CAN-24/14.75 OZ             3371850.0
# 2      FISH AK PLCK FRZ BULK CTN-49 LBS             1759296.0
# 3          CHICKEN CUT-UP FRZ CTN-40 LB              320000.0
# 4           CHICKEN SMALL CHILLED -BULK             1440000.0
# ...                                 ...                   ...
# 36012            CORN FRZ CTN-12/2.5 LB              396000.0
# 36013    MIXED VEGETABLES FRZ CTN-6/5LB               79200.0
# 36014                CORN FRZ CTN-30 LB             3009600.0
# 36015          PEAS GREEN FRZ CTN-30 LB               39600.0
# 36016                     Not Available                   0.0
#
#       Purchased Value $
# 0             4393252.2
# 1             6189008.0
# 2             2726908.8
# 3              239952.0
# 4             1047960.0
# ...                 ...
# 36012          378358.2
# 36013           72732.0
# 36014         2338987.2
# 36015           37382.4
# 36016               0.0
#
# [36017 rows x 6 columns]

# %%
cleaned_usda.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 36017 entries, 0 to 0
# Data columns (total 6 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Year                        36017 non-null  object
#  1   Origin State                36017 non-null  object
#  2   Material Group Description  36017 non-null  object
#  3   Material Description        36017 non-null  object
#  4   Purchased Quantity LB       36017 non-null  object
#  5   Purchased Value $           36017 non-null  object
# dtypes: object(6)
# memory usage: 1.9+ MB

# %%
cleaned_usda = cleaned_usda.drop(cleaned_usda[cleaned_usda['Origin State'] == 'Origin State'].index)

# %%
cleaned_usda['Purchased Quantity LB'] = cleaned_usda['Purchased Quantity LB'].astype(float)
cleaned_usda['Purchased Value $'] = cleaned_usda['Purchased Value $'].astype(float)
cleaned_usda.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 36013 entries, 0 to 0
# Data columns (total 6 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Year                        36013 non-null  object
#  1   Origin State                36013 non-null  object
#  2   Material Group Description  36013 non-null  object
#  3   Material Description        36013 non-null  object
#  4   Purchased Quantity LB       36013 non-null  float64
#  5   Purchased Value $           36013 non-null  float64
# dtypes: float64(2), object(4)
# memory usage: 1.9+ MB

# %%
# !pip install fuzzywuzzy
# Out:
# Requirement already satisfied: fuzzywuzzy in /opt/anaconda3/lib/python3.12/site-packages (0.18.0)

# %%
import re
from fuzzywuzzy import process, fuzz
import pandas as pd

# Function to clean strings by removing anything after '-' or numbers
def clean_string(name):
    # Use regex to remove everything after '-' or a number
    cleaned_name = re.split(r'-|\d', name)[0].strip()
    return cleaned_name.upper()  # Convert to uppercase for consistency

# Function to group similar names using fuzzy matching
def group_similar_names(column_data, threshold=80):
    grouped_names = {}
    for name in column_data:
        found = False
        for group_name in grouped_names.keys():
            if fuzz.partial_ratio(name, group_name) >= threshold:
                grouped_names[group_name].append(name)
                found = True
                break
        if not found:
            grouped_names[name] = [name]
    return grouped_names

def assign_general_name(grouped_names):
    general_names = {}
    for group_name, group_list in grouped_names.items():
        # Assign the first name in the group as the general category name
        general_names.update({name: group_name for name in group_list})
    return general_names

# Function to create generalized columns with cleaning logic
def create_generalized_column(df, column_name, threshold=80):
    # Clean the column data first using `clean_string`
    df[f"{column_name}_Cleaned"] = df[column_name].apply(clean_string)
    
    # Get unique cleaned values from the column
    unique_values = df[f"{column_name}_Cleaned"].unique()
    
    # Group similar names using fuzzy matching on cleaned data
    grouped_names = group_similar_names(unique_values, threshold)
    
    # Assign general names to each unique value
    general_names_map = assign_general_name(grouped_names)
    
    return df

# Apply the updated function to your DataFrame for both columns

cleaned_usda = create_generalized_column(cleaned_usda, 'Material Group Description', threshold=80)
cleaned_usda = create_generalized_column(cleaned_usda, 'Material Description', threshold=80)

# Verify results
print(cleaned_usda.head())
# Out:
#    Year Origin State Material Group Description  \
# 0  2011           AK               FISH, CANNED
# 1  2011           AK               FISH, CANNED
# 2  2011           AK               FISH, FROZEN
# 3  2011           AL            CHICKEN, FROZEN
# 4  2011           AL              CHICKEN, BULK
#
#                Material Description  Purchased Quantity LB  Purchased Value $  \
# 0       SALMON PINK CAN-24/14.75 OZ              1912042.5          4393252.2
# 1       SALMON PINK CAN-24/14.75 OZ              3371850.0          6189008.0
# 2  FISH AK PLCK FRZ BULK CTN-49 LBS              1759296.0          2726908.8
# 3      CHICKEN CUT-UP FRZ CTN-40 LB               320000.0           239952.0
# 4       CHICKEN SMALL CHILLED -BULK              1440000.0          1047960.0
#
#   Material Description_Cleaned Material Group Description_Cleaned
# 0              SALMON PINK CAN                       FISH, CANNED
# 1              SALMON PINK CAN                       FISH, CANNED
# 2    FISH AK PLCK FRZ BULK CTN                       FISH, FROZEN
# 3                  CHICKEN CUT                    CHICKEN, FROZEN
# 4        CHICKEN SMALL CHILLED                      CHICKEN, BULK

# %%
cleaned_usda.head(50)
# Out:
#     Year Origin State Material Group Description  \
# 0   2011           AK               FISH, CANNED
# 1   2011           AK               FISH, CANNED
# 2   2011           AK               FISH, FROZEN
# 3   2011           AL            CHICKEN, FROZEN
# 4   2011           AL              CHICKEN, BULK
# 5   2011           AL              CHICKEN, BULK
# 6   2011           AL            CHICKEN, COOKED
# 7   2011           AL              CHICKEN, BULK
# 8   2011           AR                RICE, GRAIN
# 9   2011           AR                RICE, GRAIN
# 10  2011           AR                RICE, GRAIN
# 11  2011           AR                RICE, GRAIN
# 12  2011           AR                RICE, GRAIN
# 13  2011           AR                RICE, GRAIN
# 14  2011           AR                RICE, GRAIN
# 15  2011           AR                RICE, GRAIN
# 16  2011           AR                RICE, GRAIN
# 17  2011           AR                RICE, GRAIN
# 18  2011           AR                RICE, GRAIN
# 19  2011           AR                RICE, GRAIN
# 20  2011           AR                RICE, GRAIN
# 21  2011           AR                RICE, GRAIN
# 22  2011           AR          VEGETABLE, CANNED
# 23  2011           AR          VEGETABLE, CANNED
# 24  2011           AR          VEGETABLE, CANNED
# 25  2011           AR          VEGETABLE, CANNED
# 26  2011           AR          VEGETABLE, CANNED
# 27  2011           AR          VEGETABLE, CANNED
# 28  2011           AR          VEGETABLE, CANNED
# 29  2011           AR             TURKEY, COOKED
# 30  2011           AR             TURKEY, COOKED
# 31  2011           AR             TURKEY, COOKED
# 32  2011           AR             TURKEY, FROZEN
# 33  2011           AR            CHICKEN, COOKED
# 34  2011           AR              CHICKEN, BULK
# 35  2011           AR              CHICKEN, BULK
# 36  2011           AR              CHICKEN, BULK
# 37  2011           AR              CHICKEN, BULK
# 38  2011           AR            CHICKEN, FROZEN
# 39  2011           AR            CHICKEN, FROZEN
# 40  2011           AR            CHICKEN, FROZEN
# 41  2011           AR            CHICKEN, FROZEN
# 42  2011           AR            CHICKEN, FROZEN
# 43  2011           AR            CHICKEN, COOKED
# 44  2011           AR            CHICKEN, COOKED
# 45  2011           AR            CHICKEN, COOKED
# 46  2011           AR            CHICKEN, COOKED
# 47  2011           AR          VEGETABLE, CANNED
# 48  2011           AR          VEGETABLE, CANNED
# 49  2011           AR          VEGETABLE, CANNED
#
#                          Material Description  Purchased Quantity LB  \
# 0                 SALMON PINK CAN-24/14.75 OZ              1912042.5
# 1                 SALMON PINK CAN-24/14.75 OZ              3371850.0
# 2            FISH AK PLCK FRZ BULK CTN-49 LBS              1759296.0
# 3                CHICKEN CUT-UP FRZ CTN-40 LB               320000.0
# 4                 CHICKEN SMALL CHILLED -BULK              1440000.0
# 5                 CHICKEN LARGE CHILLED -BULK             28908000.0
# 6             CHICKEN FAJITA STRIPS CTN-30 LB              5031000.0
# 7                 CHICKEN LARGE CHILLED -BULK             18649800.0
# 8                             RICE BRN L PRBL              1302000.0
# 9     RICE BRN US#1 LONG PARBOILED BAG-25 LB                420000.0
# 10  RICE BRN US#1 LONG PARBOILED PKG-24/2 LB               1470000.0
# 11  RICE BRN US#1 LONG PARBOILED PKG-30/2 LB                504000.0
# 12                            RICE, PARBOILED               672000.0
# 13  RICE US#1 LONG GRAIN PARBOILED BAG-25 LB                840000.0
# 14  RICE US#1 LONG GRAIN PARBOILED BAG-50 LB                 42000.0
# 15                            RICE-MLD US#2 L              7392000.0
# 16            RICE US#2 LONG GRAIN BAG-25 LB                588000.0
# 17          RICE US#2 LONG GRAIN PKG-24/2 LB               4116000.0
# 18          RICE US#2 LONG GRAIN PKG-30/2 LB               2688000.0
# 19                            RICE-MLD US#2 M              1386000.0
# 20        RICE US#2 MEDIUM GRAIN PKG-24/2 LB                420000.0
# 21        RICE US#2 MEDIUM GRAIN PKG-30/2 LB                210000.0
# 22                         CARROTS CAN-24/300              6670350.0
# 23             SWEET POTATOES MASHED CAN-6/10               224352.0
# 24                         SPINACH CAN-24/300               949620.0
# 25                     BEANS REFRIED CAN-6/10               181440.0
# 26                  BEANS VEGETARIAN CAN-6/10               594864.0
# 27                       BEANS PINTO CAN-6/10               454896.0
# 28                    BEANS BLACKEYE CAN-6/10               503699.0
# 29           TURKEY BREAST DELI FRZ CTN-40 LB              1212000.0
# 30           TURKEY BREAST DELI FRZ CTN-40 LB              2280000.0
# 31      TURKEY BREAST SMKD DELI FRZ CTN-40 LB               282800.0
# 32             TURKEY ROASTS FRZ CTN-32-48 LB                80000.0
# 33            CHICKEN FAJITA STRIPS CTN-30 LB               897000.0
# 34                CHICKEN SMALL CHILLED -BULK              6408000.0
# 35                CHICKEN SMALL CHILLED -BULK              4932000.0
# 36                 CHICKEN LEGS CHILLED -BULK                72000.0
# 37                CHICKEN THIGHS CHILLED-BULK               432000.0
# 38               CHICKEN CUT-UP FRZ CTN-40 LB               240000.0
# 39      CHICKEN WHOLE BAGGED FRZ CTN-36-43 LB               752400.0
# 40               CHICKEN CUT-UP FRZ CTN-40 LB               760000.0
# 41               CHICKEN CUT-UP FRZ CTN-40 LB               800000.0
# 42      CHICKEN CUT-UP FRZ BAGS 10/3.0-5.5 LB               157500.0
# 43                    CHICKEN DICED CTN-40 LB              1040000.0
# 44                    CHICKEN DICED CTN-40 LB               880000.0
# 45            CHICKEN FAJITA STRIPS CTN-30 LB              2964000.0
# 46    CHICKEN OVEN ROASTED FRZ 8 PC CTN-30 LB               468000.0
# 47                          HOMINY CAN-24/300               395505.0
# 48                       BEANS GREEN CAN-6/10              1316928.0
# 49                           CARROTS CAN-6/10              1697513.0
#
#     Purchased Value $     Material Description_Cleaned  \
# 0          4393252.20                  SALMON PINK CAN
# 1          6189008.00                  SALMON PINK CAN
# 2          2726908.80        FISH AK PLCK FRZ BULK CTN
# 3           239952.00                      CHICKEN CUT
# 4          1047960.00            CHICKEN SMALL CHILLED
# 5         20563408.00            CHICKEN LARGE CHILLED
# 6          9549391.00        CHICKEN FAJITA STRIPS CTN
# 7         13798608.45            CHICKEN LARGE CHILLED
# 8           810948.60                  RICE BRN L PRBL
# 9           267615.60                     RICE BRN US#
# 10          959736.94                     RICE BRN US#
# 11          338658.60                     RICE BRN US#
# 12          291009.61                  RICE, PARBOILED
# 13          295453.21                         RICE US#
# 14           13981.80                         RICE US#
# 15         2933049.00                             RICE
# 16          168254.51                         RICE US#
# 17         1420641.60                         RICE US#
# 18          929271.01                         RICE US#
# 19          690039.00                             RICE
# 20          173485.20                         RICE US#
# 21           92194.20                         RICE US#
# 22         4350850.20                      CARROTS CAN
# 23          149248.80        SWEET POTATOES MASHED CAN
# 24          570288.80                      SPINACH CAN
# 25           75254.00                BEANS REFRIED CAN
# 26          186693.00             BEANS VEGETARIAN CAN
# 27          139163.00                  BEANS PINTO CAN
# 28          149062.00               BEANS BLACKEYE CAN
# 29         3456704.80       TURKEY BREAST DELI FRZ CTN
# 30         5562573.00       TURKEY BREAST DELI FRZ CTN
# 31          791496.60  TURKEY BREAST SMKD DELI FRZ CTN
# 32          169200.00            TURKEY ROASTS FRZ CTN
# 33         2002244.41        CHICKEN FAJITA STRIPS CTN
# 34         4599518.40            CHICKEN SMALL CHILLED
# 35         3643128.00            CHICKEN SMALL CHILLED
# 36           41400.00             CHICKEN LEGS CHILLED
# 37          194400.00           CHICKEN THIGHS CHILLED
# 38          192068.00                      CHICKEN CUT
# 39          588764.00     CHICKEN WHOLE BAGGED FRZ CTN
# 40          576744.00                      CHICKEN CUT
# 41          636163.99                      CHICKEN CUT
# 42          154591.00                      CHICKEN CUT
# 43         2466568.00                CHICKEN DICED CTN
# 44         2152752.00                CHICKEN DICED CTN
# 45         5803790.00        CHICKEN FAJITA STRIPS CTN
# 46         1115233.20         CHICKEN OVEN ROASTED FRZ
# 47          189888.00                       HOMINY CAN
# 48          518695.00                  BEANS GREEN CAN
# 49          612706.00                      CARROTS CAN
#
#    Material Group Description_Cleaned
# 0                        FISH, CANNED
# 1                        FISH, CANNED
# 2                        FISH, FROZEN
# 3                     CHICKEN, FROZEN
# 4                       CHICKEN, BULK
# 5                       CHICKEN, BULK
# 6                     CHICKEN, COOKED
# 7                       CHICKEN, BULK
# 8                         RICE, GRAIN
# 9                         RICE, GRAIN
# 10                        RICE, GRAIN
# 11                        RICE, GRAIN
# 12                        RICE, GRAIN
# 13                        RICE, GRAIN
# 14                        RICE, GRAIN
# 15                        RICE, GRAIN
# 16                        RICE, GRAIN
# 17                        RICE, GRAIN
# 18                        RICE, GRAIN
# 19                        RICE, GRAIN
# 20                        RICE, GRAIN
# 21                        RICE, GRAIN
# 22                  VEGETABLE, CANNED
# 23                  VEGETABLE, CANNED
# 24                  VEGETABLE, CANNED
# 25                  VEGETABLE, CANNED
# 26                  VEGETABLE, CANNED
# 27                  VEGETABLE, CANNED
# 28                  VEGETABLE, CANNED
# 29                     TURKEY, COOKED
# 30                     TURKEY, COOKED
# 31                     TURKEY, COOKED
# 32                     TURKEY, FROZEN
# 33                    CHICKEN, COOKED
# 34                      CHICKEN, BULK
# 35                      CHICKEN, BULK
# 36                      CHICKEN, BULK
# 37                      CHICKEN, BULK
# 38                    CHICKEN, FROZEN
# 39                    CHICKEN, FROZEN
# 40                    CHICKEN, FROZEN
# 41                    CHICKEN, FROZEN
# 42                    CHICKEN, FROZEN
# 43                    CHICKEN, COOKED
# 44                    CHICKEN, COOKED
# 45                    CHICKEN, COOKED
# 46                    CHICKEN, COOKED
# 47                  VEGETABLE, CANNED
# 48                  VEGETABLE, CANNED
# 49                  VEGETABLE, CANNED

# %%
cleaned_usda.to_csv('cleaned_usda_f.csv')
